# %%
import numpy as np
import pandas as pd
import folium

오름 = pd.read_csv('o.csv', encoding='cp949')
from folium.features import CustomIcon

m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'

주차장유 = folium.FeatureGroup(name='주차장유').add_to(m)
주차장무 = folium.FeatureGroup(name='주차장무').add_to(m)
화장실유 = folium.FeatureGroup(name='화장실유').add_to(m)
화장실무 = folium.FeatureGroup(name='화장실무').add_to(m)

for i in range(오름.shape[0]):
    if 오름.iloc[i]["주차장"] == 'Y':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(주차장유)
    else:
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(주차장무)
for i in range(오름.shape[0]):
    if 오름.iloc[i]["화장실"] == 'Y':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(화장실유)
    else:
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(화장실무)
        
        
folium.LayerControl(collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_170478c670e2e61b4f5217cd4dc60ab5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_170478c670e2e61b4f5217cd4dc60ab5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_170478c670e2e61b4f5217cd4dc60ab5 = L.map(
#                 &quot;map_170478c670e2e61b4f5217cd4dc60ab5&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e80df51b8fe4e38cdfdfd0b163832bbc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_170478c670e2e61b4f5217cd4dc60ab5);
#
#
#             var feature_group_82fbc24d13bbb4c873554f7882f05622 = L.featureGroup(
#                 {}
#             ).addTo(map_170478c670e2e61b4f5217cd4dc60ab5);
#
#
#             var marker_ccadc74159fb652823262496d031ab83 = L.marker(
#                 [33.1994088, 126.2907797],
#                 {}
#             ).addTo(feature_group_82fbc24d13bbb4c873554f7882f05622);
#
#
#         var popup_32f76ce039c38f9a69d259b54052ac58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e76a5517194277d0038a7dd580714a79 = $(`&lt;div id=&quot;html_e76a5517194277d0038a7dd580714a79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;송악산(절울이)&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_32f76ce039c38f9a69d259b54052ac58.setContent(html_e76a5517194277d0038a7dd580714a79);
#
#
#         marker_ccadc74159fb652823262496d031ab83.bindPopup(popup_32f76ce039c38f9a69d259b54052ac58)
#         ;
#
#
#
#
#             marker_ccadc74159fb652823262496d031ab83.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a66302569ca873440b7f2f041f8e25ec = L.marker(
#                 [33.2042537, 126.281676],
#                 {}
#             ).addTo(feature_group_82fbc24d13bbb4c873554f7882f05622);
#
#
#         var popup_6fd51221f7e310f14395fa053cfd3e48 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7f33be7477f873613174f7a52aa7f2e6 = $(`&lt;div id=&quot;html_7f33be7477f873613174f7a52aa7f2e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;섯알오름&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_6fd51221f7e310f14395fa053cfd3e48.setContent(html_7f33be7477f873613174f7a52aa7f2e6);
#
#
#         marker_a66302569ca873440b7f2f041f8e25ec.bindPopup(popup_6fd51221f7e310f14395fa053cfd3e48)
#         ;
#
#
#
#
#             marker_a66302569ca873440b7f2f041f8e25ec.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b383eec9ff7bae3367dc5c4500a42cac = L.marker(
#                 [33.3708091, 126.6935196],
#                 {}
#             ).addTo(feature_group_82fbc24d13bbb4c873554f7882f05622);
#
#
#         var popup_dcb3300cfde189696493523bbb55eabd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1cda3b1391b563a575f9ef443c36fd97 = $(`&lt;div id=&quot;html_1cda3b1391b563a575f9ef443c36fd97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;물영아리&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : N&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_dcb3300cfde189696493523bbb55eabd.setContent(html_1cda3b1391b563a575f9ef443c36fd97);
#
#
#         marker_b383eec9ff7bae3367dc5c4500a42cac.bindPopup(popup_dcb3300cfde189696493523bbb55eabd)
#         ;
#
#
#
#
#             marker_b383eec9ff7bae3367dc5c4500a42cac.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b65096196781fb95da3305dca67173e6 = L.marker(
#                 [33.342895, 126.6494133],
#                 {}
#             ).addTo(feature_group_82fbc24d13bbb4c873554f7882f05622);
#
#
#         var popup_37583dcc6abfb51d5d18a04bafbe6391 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_85070e6309870c2667de620f02576aec = $(`&lt;div id=&quot;html_85070e6309870c2667de620f02576aec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;머체오름&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&
