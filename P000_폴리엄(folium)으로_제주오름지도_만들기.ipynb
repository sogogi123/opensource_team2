# %%
# !pip3 install folium
# Out:
# Requirement already satisfied: folium in c:\users\user\anaconda3\lib\site-packages (0.12.1.post1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from folium) (1.20.3)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from folium) (2.26.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from folium) (0.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)

# %%
import numpy as np
import pandas as pd
import folium

# %%
import warnings

warnings.filterwarnings(action='ignore')

# %%
#한글깨짐 해결
# !pip3 install git+https://github.com/python-visualization/branca.git@master
# Out:
# Collecting git+https://github.com/python-visualization/branca.git@master
#   Cloning https://github.com/python-visualization/branca.git (to revision master) to c:\users\user\appdata\local\temp\pip-req-build-e1pbj_m9
#   Resolved https://github.com/python-visualization/branca.git to commit 52b10bd969ac25d0b70640b2eee2ea1d8e8690b3
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from branca==0.5.0+5.g52b10bd) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->branca==0.5.0+5.g52b10bd) (1.1.1)
# Building wheels for collected packages: branca
#   Building wheel for branca (setup.py): started
#   Building wheel for branca (setup.py): finished with status 'done'
#   Created wheel for branca: filename=branca-0.5.0+5.g52b10bd-py3-none-any.whl size=24515 sha256=a4e1b5e204f6de4aa79cd81ea3c8e8c361be6c071b73b52824e0a43d7082dafe
#   Stored in directory: C:\Users\USER\AppData\Local\Temp\pip-ephem-wheel-cache-pc5xz61g\wheels\90\e5\13\eccb91011560564109ba4ebad51c8a1a32f5ba65112e7bcb03
# Successfully built branca
# Installing collected packages: branca
#   Attempting uninstall: branca
#     Found existing installation: branca 0.5.0
#     Uninstalling branca-0.5.0:
#       Successfully uninstalled branca-0.5.0
# Successfully installed branca-0.5.0+5.g52b10bd
#   Running command git clone -q https://github.com/python-visualization/branca.git 'C:\Users\USER\AppData\Local\Temp\pip-req-build-e1pbj_m9'

# %%
m = folium.Map(
    location=[33.3684955195788, 126.52918183373025]
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5944320a2e3d74420bfcfff5aa844ec0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5944320a2e3d74420bfcfff5aa844ec0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5944320a2e3d74420bfcfff5aa844ec0 = L.map(
#                 &quot;map_5944320a2e3d74420bfcfff5aa844ec0&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e23a516e21e601fed69d4baa23cd64bb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5944320a2e3d74420bfcfff5aa844ec0);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('index.html')

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start = 10
)

tooltip = 'Click!!'

folium.Marker(
    [33.3684955195788, 126.52918183373025],
    popup = '<strong>hello world</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b06b9defd0fa3ec36e6e2a0f6a2909fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b06b9defd0fa3ec36e6e2a0f6a2909fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b06b9defd0fa3ec36e6e2a0f6a2909fc = L.map(
#                 &quot;map_b06b9defd0fa3ec36e6e2a0f6a2909fc&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d8f6e5f7d4159b05b826455b2d8ee5c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b06b9defd0fa3ec36e6e2a0f6a2909fc);
#
#
#             var marker_881109aaadfe30df5e63c363c536a2c2 = L.marker(
#                 [33.3684955195788, 126.52918183373025],
#                 {}
#             ).addTo(map_b06b9defd0fa3ec36e6e2a0f6a2909fc);
#
#
#         var popup_b7fd5cae14790bb7adea03007980dac9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d1b49309ae88430c09087c969f4c36e9 = $(`&lt;div id=&quot;html_d1b49309ae88430c09087c969f4c36e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello world&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_b7fd5cae14790bb7adea03007980dac9.setContent(html_d1b49309ae88430c09087c969f4c36e9);
#
#
#         marker_881109aaadfe30df5e63c363c536a2c2.bindPopup(popup_b7fd5cae14790bb7adea03007980dac9)
#         ;
#
#
#
#
#             marker_881109aaadfe30df5e63c363c536a2c2.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start = 10
)

tooltip = 'Click!!'

folium.Marker(
    [33.3684955195788, 126.52918183373025],
    popup = '<strong>한라산</strong>',
    tooltip = tooltip
).add_to(m)

folium.Marker(
    [33.51048502651309, 126.49132121516628],
    popup = '<strong>제주국제공항</strong>',
    tooltip = tooltip
).add_to(m)

folium.Marker(
    [33.508461049711265, 126.54097984346038],
    popup = '<strong>바울랩</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35692\423617776.py in <module>
# ----> 1 m = folium.Map(
#       2     location = [33.3684955195788, 126.52918183373025],
#       3     #tiles = 'Stamen Terrain',
#       4     zoom_start = 10
#       5 )
#
# NameError: name 'folium' is not defined

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start = 10
)

tooltip = 'Click!!'

folium.Marker(
    [33.3684955195788, 126.52918183373025],
    popup = '<strong>한라산</strong>',
    tooltip = tooltip,
    icon = folium.Icon(color='#ff0000', icon='info-sign')
).add_to(m)

folium.Marker(
    [33.51048502651309, 126.49132121516628],
    popup = '<strong>제주국제공항</strong>',
    tooltip = tooltip,
    icon = folium.Icon(color='green', icon='bookmark')
).add_to(m)

folium.Marker(
    [33.508461049711265, 126.54097984346038],
    popup = '<strong>바울랩</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70f0b069b849518b21c279c4806d5ff7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70f0b069b849518b21c279c4806d5ff7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_70f0b069b849518b21c279c4806d5ff7 = L.map(
#                 &quot;map_70f0b069b849518b21c279c4806d5ff7&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ef473680dcde8726f5039fd53d0da06 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_70f0b069b849518b21c279c4806d5ff7);
#
#
#             var marker_0ed5c24c34b16e8dabdb83d8416a9f9c = L.marker(
#                 [33.3684955195788, 126.52918183373025],
#                 {}
#             ).addTo(map_70f0b069b849518b21c279c4806d5ff7);
#
#
#             var icon_f7ff6fa9595d335615dc37cf7f4eff5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;#ff0000&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0ed5c24c34b16e8dabdb83d8416a9f9c.setIcon(icon_f7ff6fa9595d335615dc37cf7f4eff5c);
#
#
#         var popup_a366628f71ed86de1bde40c11078d1e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0c2fde53b8983e43222e7fbb6454f05a = $(`&lt;div id=&quot;html_0c2fde53b8983e43222e7fbb6454f05a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;한라산&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_a366628f71ed86de1bde40c11078d1e5.setContent(html_0c2fde53b8983e43222e7fbb6454f05a);
#
#
#         marker_0ed5c24c34b16e8dabdb83d8416a9f9c.bindPopup(popup_a366628f71ed86de1bde40c11078d1e5)
#         ;
#
#
#
#
#             marker_0ed5c24c34b16e8dabdb83d8416a9f9c.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_77d5d456fd74bea4475be0ab6d736e5a = L.marker(
#                 [33.51048502651309, 126.49132121516628],
#                 {}
#             ).addTo(map_70f0b069b849518b21c279c4806d5ff7);
#
#
#             var icon_aa6b5505a8f3055d624016a18ff9b627 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_77d5d456fd74bea4475be0ab6d736e5a.setIcon(icon_aa6b5505a8f3055d624016a18ff9b627);
#
#
#         var popup_5c1367a4dac5413fe4ffa602c8d4c5f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b2df424f98db14290b69d3f82775172c = $(`&lt;div id=&quot;html_b2df424f98db14290b69d3f82775172c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;제주국제공항&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_5c1367a4dac5413fe4ffa602c8d4c5f0.setContent(html_b2df424f98db14290b69d3f82775172c);
#
#
#         marker_77d5d456fd74bea4475be0ab6d736e5a.bindPopup(popup_5c1367a4dac5413fe4ffa602c8d4c5f0)
#         ;
#
#
#
#
#             marker_77d5d456fd74bea4475be0ab6d736e5a.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_55b426d7e943d7a2c8a4ee340fc33c88 = L.marker(
#                 [33.508461049711265, 126.54097984346038],
#                 {}
#             ).addTo(map_70f0b069b849518b21c279c4806d5ff7);
#
#
#         var popup_cd6d0d76923213181534add4e2ee5fd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_56de33b2c4ee8c686b6e661172aff694 = $(`&lt;div id=&quot;html_56de33b2c4ee8c686b6e661172aff694&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;바울랩&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_cd6d0d76923213181534add4e2ee5fd6.setContent(html_56de33b2c4ee8c686b6e661172aff694);
#
#
#         marker_55b426d7e943d7a2c8a4ee340fc33c88.bindPopup(popup_cd6d0d76923213181534add4e2ee5fd6)
#         ;
#
#
#
#
#             marker_55b426d7e943d7a2c8a4ee340fc33c88.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import numpy as np
import pandas as pd
import folium

# %%
오름 = pd.read_csv('o.csv', encoding='cp949')
오름.head()
오름.tail()
# Out:
#     읍면동    오름명                      소재지         위도          경도 주차장 화장실  표고(m)  \
# 63  서홍동    시오름     제주특별자치도 서귀포시 서홍동 산 1  33.361667  126.529167   N   N  757.8
# 64  대륜동    고근산  제주특별자치도 서귀포시 서호동 1286-1  33.266364  126.512309   Y   Y  396.2
# 65  중문동   거린사슴   제주특별자치도 서귀포시 대포동 산 2-1  33.307313  126.454127   Y   Y  742.9
# 66  중문동  베릿내오름    제주특별자치도 서귀포시 중문동 3712  33.251430  126.434824   Y   Y  101.2
# 67  중문동    법정악     제주특별자치도 서귀포시 하원동 산 1  33.258346  126.452100   Y   Y  760.1
#
#        데이터기준일자
# 63  2021-05-10
# 64  2021-05-10
# 65  2021-05-10
# 66  2021-05-10
# 67  2021-05-10

# %%
오름.isnull()
오름.isnull().sum()
# Out:
# 읍면동        0
# 오름명        0
# 소재지        0
# 위도         0
# 경도         0
# 주차장        0
# 화장실        0
# 표고(m)      0
# 데이터기준일자    0
# dtype: int64

# %%
오름[['화장실']].value_counts()
# Out:
# 화장실
# N      40
# Y      28
# dtype: int64

# %%
오름[['주차장']].value_counts()
# Out:
# 주차장
# Y      35
# N      33
# dtype: int64

# %%
오름.iloc[0]
오름.iloc[0]['오름명']
오름.iloc[0]['위도']
오름.iloc[0]['경도']
# Out:
# 126.2907797

# %%
오름.shape
# Out:
# (68, 9)

# %%
for i in range(오름.shape[0]):
    print(오름.iloc[i]['오름명'], 오름.iloc[i]['위도'], 오름.iloc[i]['경도'])
# Out:
# 송악산(절울이) 33.1994088 126.2907797
# 섯알오름 33.2042537 126.281676
# 가시오름  33.2533626 126.2490546
# 녹남봉 33.2798153 126.1954827
# 물영아리 33.3708091 126.6935196
# 머체오름 33.342895 126.6494133
# 이승이 33.342895 126.6494133
# 사려니오름 33.342895 126.6494133
# 민오름 33.3508829 126.6980129
# 운지오름 33.320538 126.7451549
# 자배봉 33.342895 126.6494133
# 생길이 33.342895 126.6494133
# 큰걸세 33.3616666 126.5291666
# 족은걸세 33.3616666 126.5291666
# 수악 33.3616666 126.5291666
# 한남리머체왓숲길 33.3305697 126.6740675
# 일출봉 33.4584473 126.9425348
# 멀미오름 33.4786495 126.8840616
# 멀미알오름 33.4786495 126.8840616
# 식산봉(바우오름) 33.4656758 126.9196473
# 큰물메(대왕수봉) 33.4398545 126.8991383
# 궁대악 33.4349078 126.8170896
# 뒤꾸부니 33.4310244 126.8273298
# 모구리오름 33.4080291 126.8271111
# 유건에오름 33.4135945 126.8467892
# 통오름 33.3944955 126.8567401
# 독자봉 33.3877114 126.8541774
# 남산봉 33.3860915 126.8081632
# 낭끼오름 33.4355716 126.842924
# 모구리알오름 33.4080291 126.8271111
# 대왕산 33.456482 126.8727771
# 군산 33.2551426 126.3683605
# 단산(바굼지오름) 33.2469709 126.3206311
# 월라봉(다래오름) 33.2442794 126.3499008
# 대병악(여진머리) 33.3066236 126.3704559
# 북오름 33.3056468 126.3313681
# 남송악(남소로기) 33.3050158 126.3046682
# 광해악(넙게오름) 33.2871076 126.3162332
# 논오름 33.2666345 126.3408035
# 금산 33.2360818 126.2870485
# 용머리 33.2340447 126.3141969
# 왕이메 33.340233 126.374785
# 따라비오름 33.3708091 126.6935196
# 대록산(큰사슴이) 33.3708091 126.6935196
# 달산봉 33.3485734 126.8327895
# 제석오름 33.3470334 126.836251
# 매봉 33.3225332 126.8228665
# 영주산 33.4048901 126.7976481
# 좌보미 33.4377473 126.7917034
# 백약이오름 33.4377473 126.7917034
# 갑선이 33.3708091 126.6935196
# 가세오름 33.3314602 126.7815087
# 토산봉 33.3223939 126.7735897
# 붉은오름 33.3708091 126.6935196
# 개오름 33.3863435 126.7997102
# 갑마장길 33.3708091 126.6935196
# 제지오름(절오름) 33.240809 126.6101421
# 월라산(도라미) 33.2705143 126.6046518
# 칡오름 33.3616666 126.5291666
# 영천오름 33.3616666 126.5291666
# 미악산(솔오름) 33.3017594 126.5573394
# 삼매봉 33.2539385 126.5595922
# 하논-보로미 33.2537823 126.5422628
# 시오름 33.3616666 126.5291666
# 고근산 33.2663637 126.5123088
# 거린사슴 33.3073127 126.4541266
# 베릿내오름 33.2514303 126.4348243
# 법정악 33.2583461 126.4521002

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'

for i in range(오름.shape[0]):
    folium.Marker(
        [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
        popup = f'<strong>{오름.iloc[i]["오름명"]}</strong>',
        tooltip = tooltip
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f4530c2e0d5a6de13ca220b4306107d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f4530c2e0d5a6de13ca220b4306107d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1f4530c2e0d5a6de13ca220b4306107d = L.map(
#                 &quot;map_1f4530c2e0d5a6de13ca220b4306107d&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2028710e8e0b10b0ec54d1609c68a5c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1f4530c2e0d5a6de13ca220b4306107d);
#
#
#             var marker_3f7464d82aad93030d1d3bada1face5d = L.marker(
#                 [33.1994088, 126.2907797],
#                 {}
#             ).addTo(map_1f4530c2e0d5a6de13ca220b4306107d);
#
#
#         var popup_38ba7a9d93a7529d3fb2ea8225b0ffed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d40046c95a601097e61ee718ddb6d48f = $(`&lt;div id=&quot;html_d40046c95a601097e61ee718ddb6d48f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;송악산(절울이)&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_38ba7a9d93a7529d3fb2ea8225b0ffed.setContent(html_d40046c95a601097e61ee718ddb6d48f);
#
#
#         marker_3f7464d82aad93030d1d3bada1face5d.bindPopup(popup_38ba7a9d93a7529d3fb2ea8225b0ffed)
#         ;
#
#
#
#
#             marker_3f7464d82aad93030d1d3bada1face5d.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_90d608666afcbff1151d3033953b57d3 = L.marker(
#                 [33.2042537, 126.281676],
#                 {}
#             ).addTo(map_1f4530c2e0d5a6de13ca220b4306107d);
#
#
#         var popup_30b9d8b8f94973be80fd728f26f7a418 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_58a1ecd48ef1850901dc90ce8a02d9e8 = $(`&lt;div id=&quot;html_58a1ecd48ef1850901dc90ce8a02d9e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;섯알오름&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_30b9d8b8f94973be80fd728f26f7a418.setContent(html_58a1ecd48ef1850901dc90ce8a02d9e8);
#
#
#         marker_90d608666afcbff1151d3033953b57d3.bindPopup(popup_30b9d8b8f94973be80fd728f26f7a418)
#         ;
#
#
#
#
#             marker_90d608666afcbff1151d3033953b57d3.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6c3f388a9acd9170f81a8ecc833080a8 = L.marker(
#                 [33.2533626, 126.2490546],
#                 {}
#             ).addTo(map_1f4530c2e0d5a6de13ca220b4306107d);
#
#
#         var popup_b9ddc1ac160368a34a6d4d4bd9d0f5f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_141b898727f9a9647c6ead0243b1cbdc = $(`&lt;div id=&quot;html_141b898727f9a9647c6ead0243b1cbdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;가시오름 &lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_b9ddc1ac160368a34a6d4d4bd9d0f5f9.setContent(html_141b898727f9a9647c6ead0243b1cbdc);
#
#
#         marker_6c3f388a9acd9170f81a8ecc833080a8.bindPopup(popup_b9ddc1ac160368a34a6d4d4bd9d0f5f9)
#         ;
#
#
#
#
#             marker_6c3f388a9acd9170f81a8ecc833080a8.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c6a509ecc11ae7df78aea2ef003166d8 = L.marker(
#                 [33.2798153, 126.1954827],
#                 {}
#             ).addTo(map_1f4530c2e0d5a6de13ca220b4306107d);
#
#
#         var popup_1f0bddfa95cb79b6c7322d774e396940 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0573cc24ef57dde714e30c0c9c049c50 = $(`&lt;div id=&quot;html_0573cc24ef57dde714e30c0c9c049c50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;녹남봉&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_1f0bddfa95cb79b6c7322d774e396940.setContent(html_0573cc24ef57dde714e30c0c9c049c50);
#
#
#         marker_c6a509ecc11ae7df78aea2ef003166d8.bindPopup(popup_1f0bddfa95cb79b6c7322d774e396940)
#         ;
#
#
#
#
#             marker_c6a509ecc11ae7df78aea2ef003166d8.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cbd8a3167af57a534a449087b9663271 = L.marker(
#                 [33.3708091, 126.6935196],
#                 {}
#             ).addTo(map_1f4530c2e0d5a6de1

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'

for i in range(오름.shape[0]):
    folium.Marker(
        [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
        popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
        주차장 : {오름.iloc[i]["주차장"]}<br>\
        화장실 : {오름.iloc[i]["화장실"]}<br>\
        </div>',
        tooltip = tooltip
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f167452a970710542857f78b3e38282 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f167452a970710542857f78b3e38282&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9f167452a970710542857f78b3e38282 = L.map(
#                 &quot;map_9f167452a970710542857f78b3e38282&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1086db45331359b003f63df7bd1fa22 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f167452a970710542857f78b3e38282);
#
#
#             var marker_2028e242dda3efc3074ee3413d922ce8 = L.marker(
#                 [33.1994088, 126.2907797],
#                 {}
#             ).addTo(map_9f167452a970710542857f78b3e38282);
#
#
#         var popup_90b1046d2780e5dedf83fc9c01188840 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1af11ccf57c674cee196072ef5f163e4 = $(`&lt;div id=&quot;html_1af11ccf57c674cee196072ef5f163e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;송악산(절울이)&lt;/strong&gt;&lt;br&gt;        주차장 : Y&lt;br&gt;        화장실 : Y&lt;br&gt;        &lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_90b1046d2780e5dedf83fc9c01188840.setContent(html_1af11ccf57c674cee196072ef5f163e4);
#
#
#         marker_2028e242dda3efc3074ee3413d922ce8.bindPopup(popup_90b1046d2780e5dedf83fc9c01188840)
#         ;
#
#
#
#
#             marker_2028e242dda3efc3074ee3413d922ce8.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7a93e0f6639492d8e5cb8826c6d8915b = L.marker(
#                 [33.2042537, 126.281676],
#                 {}
#             ).addTo(map_9f167452a970710542857f78b3e38282);
#
#
#         var popup_6cb134164be2a752e4f0260be2e68ced = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2aaa2488f61e8b2f6ab8a7b6df9fa62c = $(`&lt;div id=&quot;html_2aaa2488f61e8b2f6ab8a7b6df9fa62c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;섯알오름&lt;/strong&gt;&lt;br&gt;        주차장 : Y&lt;br&gt;        화장실 : Y&lt;br&gt;        &lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_6cb134164be2a752e4f0260be2e68ced.setContent(html_2aaa2488f61e8b2f6ab8a7b6df9fa62c);
#
#
#         marker_7a93e0f6639492d8e5cb8826c6d8915b.bindPopup(popup_6cb134164be2a752e4f0260be2e68ced)
#         ;
#
#
#
#
#             marker_7a93e0f6639492d8e5cb8826c6d8915b.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a706cbc645caec1f572cd9adccff217a = L.marker(
#                 [33.2533626, 126.2490546],
#                 {}
#             ).addTo(map_9f167452a970710542857f78b3e38282);
#
#
#         var popup_6403aa1099ba0386de679c9b52a1e734 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e89911df581f70b8957cd72a04a2e28 = $(`&lt;div id=&quot;html_7e89911df581f70b8957cd72a04a2e28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;가시오름 &lt;/strong&gt;&lt;br&gt;        주차장 : N&lt;br&gt;        화장실 : N&lt;br&gt;        &lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_6403aa1099ba0386de679c9b52a1e734.setContent(html_7e89911df581f70b8957cd72a04a2e28);
#
#
#         marker_a706cbc645caec1f572cd9adccff217a.bindPopup(popup_6403aa1099ba0386de679c9b52a1e734)
#         ;
#
#
#
#
#             marker_a706cbc645caec1f572cd9adccff217a.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_762e7eed33b3115d463ddf2a906baa8b = L.marker(
#                 [33.2798153, 126.1954827],
#                 {}
#             ).addTo(map_9f167452a970710542857f78b3e38282);
#
#
#         var popup_565578cdd2c088b73cf40617d0424010 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_279a854ff93fa34353a64a9674591de9 = $(`&lt;div id=&quot;html_279a854ff93fa34353a64a9674591de9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;녹남봉&lt;/strong&gt;&lt;br&gt;        주차장 : N&lt;br&gt;        화장실 : N&lt;br&gt;        &lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_565578cdd2c088b73cf40617d0424010.setContent(html_279a854ff93fa34353a64a9674591de9);
#
#
#         marker_762e7eed33b3115d463ddf2a906

# %%
오름['이미지'] = 오름['오름명']+'.jpg'
오름
# Out:
#     읍면동       오름명                         소재지         위도          경도 주차장 화장실  \
# 0   대정읍  송악산(절울이)    제주특별자치도 서귀포시 대정읍 상모리 산 2  33.199409  126.290780   Y   Y
# 1   대정읍      섯알오름   제주특별자치도 서귀포시 대정읍 상모리 1618  33.204254  126.281676   Y   Y
# 2   대정읍     가시오름    제주특별자치도 서귀포시 대정읍 동일리 1209  33.253363  126.249055   N   N
# 3   대정읍       녹남봉   제주특별자치도 서귀포시 대정읍 신도리 1304  33.279815  126.195483   N   N
# 4   남원읍      물영아리  제주특별자치도 서귀포시 남원읍 수망리 산 189  33.370809  126.693520   Y   N
# ..  ...       ...                         ...        ...         ...  ..  ..
# 63  서홍동       시오름        제주특별자치도 서귀포시 서홍동 산 1  33.361667  126.529167   N   N
# 64  대륜동       고근산     제주특별자치도 서귀포시 서호동 1286-1  33.266364  126.512309   Y   Y
# 65  중문동      거린사슴      제주특별자치도 서귀포시 대포동 산 2-1  33.307313  126.454127   Y   Y
# 66  중문동     베릿내오름       제주특별자치도 서귀포시 중문동 3712  33.251430  126.434824   Y   Y
# 67  중문동       법정악        제주특별자치도 서귀포시 하원동 산 1  33.258346  126.452100   Y   Y
#
#     표고(m)     데이터기준일자           이미지
# 0   104.0  2021-05-10  송악산(절울이).jpg
# 1    40.7  2021-05-10      섯알오름.jpg
# 2   106.5  2021-05-10     가시오름 .jpg
# 3   100.4  2021-05-10       녹남봉.jpg
# 4   508.0  2021-05-10      물영아리.jpg
# ..    ...         ...           ...
# 63  757.8  2021-05-10       시오름.jpg
# 64  396.2  2021-05-10       고근산.jpg
# 65  742.9  2021-05-10      거린사슴.jpg
# 66  101.2  2021-05-10     베릿내오름.jpg
# 67  760.1  2021-05-10       법정악.jpg
#
# [68 rows x 10 columns]

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'

for i in range(오름.shape[0]):
    folium.Marker(
        [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
        popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
        주차장 : {오름.iloc[i]["주차장"]}<br>\
        화장실 : {오름.iloc[i]["화장실"]}<br>\
        <img width="80px" src="a.jpg"><br>\
        <a href="https://www.visitjeju.net/kr/search?q=%EC%98%A4%EB%A6%84#">상세페이지 이동</a></div>',
        tooltip = tooltip
    ).add_to(m)

m.save('index.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65d2e759837c7e2cbfb32fd6114ef3f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65d2e759837c7e2cbfb32fd6114ef3f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_65d2e759837c7e2cbfb32fd6114ef3f4 = L.map(
#                 &quot;map_65d2e759837c7e2cbfb32fd6114ef3f4&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd628457589ecae82edd88afb64833de = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_65d2e759837c7e2cbfb32fd6114ef3f4);
#
#
#             var marker_c1fdb3ad5d9fc79fc767259a7c7567a8 = L.marker(
#                 [33.1994088, 126.2907797],
#                 {}
#             ).addTo(map_65d2e759837c7e2cbfb32fd6114ef3f4);
#
#
#         var popup_90d8627e36dcb5bb3628b9fbc7f12431 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3a1288a31fe4037551f29d0cfd43d029 = $(`&lt;div id=&quot;html_3a1288a31fe4037551f29d0cfd43d029&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;송악산(절울이)&lt;/strong&gt;&lt;br&gt;        주차장 : Y&lt;br&gt;        화장실 : Y&lt;br&gt;        &lt;img width=&quot;80px&quot; src=&quot;a.jpg&quot;&gt;&lt;br&gt;        &lt;a href=&quot;https://www.visitjeju.net/kr/search?q=%EC%98%A4%EB%A6%84#&quot;&gt;상세페이지 이동&lt;/a&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_90d8627e36dcb5bb3628b9fbc7f12431.setContent(html_3a1288a31fe4037551f29d0cfd43d029);
#
#
#         marker_c1fdb3ad5d9fc79fc767259a7c7567a8.bindPopup(popup_90d8627e36dcb5bb3628b9fbc7f12431)
#         ;
#
#
#
#
#             marker_c1fdb3ad5d9fc79fc767259a7c7567a8.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0948d97a916ccf2b01b427dcb8bac927 = L.marker(
#                 [33.2042537, 126.281676],
#                 {}
#             ).addTo(map_65d2e759837c7e2cbfb32fd6114ef3f4);
#
#
#         var popup_36c9f1f68e8851adea1915d99237f412 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dd126079c8671661cace9f15052f3c65 = $(`&lt;div id=&quot;html_dd126079c8671661cace9f15052f3c65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;섯알오름&lt;/strong&gt;&lt;br&gt;        주차장 : Y&lt;br&gt;        화장실 : Y&lt;br&gt;        &lt;img width=&quot;80px&quot; src=&quot;a.jpg&quot;&gt;&lt;br&gt;        &lt;a href=&quot;https://www.visitjeju.net/kr/search?q=%EC%98%A4%EB%A6%84#&quot;&gt;상세페이지 이동&lt;/a&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_36c9f1f68e8851adea1915d99237f412.setContent(html_dd126079c8671661cace9f15052f3c65);
#
#
#         marker_0948d97a916ccf2b01b427dcb8bac927.bindPopup(popup_36c9f1f68e8851adea1915d99237f412)
#         ;
#
#
#
#
#             marker_0948d97a916ccf2b01b427dcb8bac927.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7c20f3692783f0b1e782069aade70443 = L.marker(
#                 [33.2533626, 126.2490546],
#                 {}
#             ).addTo(map_65d2e759837c7e2cbfb32fd6114ef3f4);
#
#
#         var popup_472fe56eb868c3da51efe820a35ca391 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4fdb7d8a7a5cc1b6a55ff6b8524c8b57 = $(`&lt;div id=&quot;html_4fdb7d8a7a5cc1b6a55ff6b8524c8b57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;가시오름 &lt;/strong&gt;&lt;br&gt;        주차장 : N&lt;br&gt;        화장실 : N&lt;br&gt;        &lt;img width=&quot;80px&quot; src=&quot;a.jpg&quot;&gt;&lt;br&gt;        &lt;a href=&quot;https://www.visitjeju.net/kr/search?q=%EC%98%A4%EB%A6%84#&quot;&gt;상세페이지 이동&lt;/a&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_472fe56eb868c3da51efe820a35ca391.setContent(html_4fdb7d8a7a5cc1b6a55ff6b8524c8b57);
#
#
#         marker_7c20f3692783f0b1e782069aade70443.bindPopup(popup_472fe56eb868c3da51efe820a35ca391)
#         ;
#
#
#
#
#             marker_7c20f3692783f0b1e782069aade70443.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f88092a9f8046eac3c1de12245e25ad4 = L.marker(
#                 [33.2798153, 126.1954827],
#                 {}
#             ).addTo(map_65d2e759837c7e2cbfb32fd6114ef3f4);
#
#
#         var popup_a5ceefb7e12af3eee786e18dbaca9e42 = L.popup({&quot;maxWidth&quot;:
