# %%
import numpy as np
import pandas as pd
import folium

# %%
오름 = pd.read_csv('o.csv', encoding='cp949')

# %%
from folium.features import CustomIcon

m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'


for i in range(오름.shape[0]):

    icon_image = 'mountain.png'
    icon = CustomIcon(
        icon_image,
        icon_size = (20, 20),
        popup_anchor = (30, -30),
    )
    
    folium.Marker(
        [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
        popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
        주차장 : {오름.iloc[i]["주차장"]}<br>\
        화장실 : {오름.iloc[i]["화장실"]}<br>',
        tooltip = tooltip,
        icon = icon
    ).add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11012/4151970193.py in <module>
#      12
#      13     icon_image = 'mountain.png'
# ---> 14     icon = CustomIcon(
#      15         icon_image,
#      16         icon_size = (20, 20),
#
# ~\anaconda3\lib\site-packages\folium\features.py in __init__(self, icon_image, icon_size, icon_anchor, shadow_image, shadow_size, shadow_anchor, popup_anchor)
#    1463         self._name = 'CustomIcon'
#    1464         self.options = parse_options(
# -> 1465             icon_url=image_to_url(icon_image),
#    1466             icon_size=icon_size,
#    1467             icon_anchor=icon_anchor,
#
# ~\anaconda3\lib\site-packages\folium\utilities.py in image_to_url(image, colormap, origin)
#     132     if isinstance(image, str) and not _is_url(image):
#     133         fileformat = os.path.splitext(image)[-1][1:]
# --> 134         with io.open(image, 'rb') as f:
#     135             img = f.read()
#     136         b64encoded = base64.b64encode(img).decode('utf-8')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mountain.png'

# %%
from folium.features import CustomIcon

m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'

주차장유 = folium.FeatureGroup(name='주차장유').add_to(m)
주차장무 = folium.FeatureGroup(name='주차장무').add_to(m)
화장실유 = folium.FeatureGroup(name='화장실유').add_to(m)
화장실무 = folium.FeatureGroup(name='화장실무').add_to(m)


for i in range(오름.shape[0]):
    if 오름.iloc[i]["주차장"] == 'Y':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(주차장유)
    else:
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(주차장무)
        
for i in range(오름.shape[0]):
    if 오름.iloc[i]["화장실"] == 'Y':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(화장실유)
    else:
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(화장실무)

folium.LayerControl(collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8172b95fabc516f0fc7e8d4955743d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8172b95fabc516f0fc7e8d4955743d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b8172b95fabc516f0fc7e8d4955743d5 = L.map(
#                 &quot;map_b8172b95fabc516f0fc7e8d4955743d5&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_429fe3bab476c850bf0845ef663b3ad8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b8172b95fabc516f0fc7e8d4955743d5);
#
#
#             var feature_group_a3d6b7a64d2063a7d40b9477dbf00ba1 = L.featureGroup(
#                 {}
#             ).addTo(map_b8172b95fabc516f0fc7e8d4955743d5);
#
#
#             var marker_027f0fc06de4933bd4247b409950f49b = L.marker(
#                 [33.1994088, 126.2907797],
#                 {}
#             ).addTo(feature_group_a3d6b7a64d2063a7d40b9477dbf00ba1);
#
#
#         var popup_41832eb6330c4e389e47178620179ea7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5335bbcd624aeedfd418f1f2a4f78568 = $(`&lt;div id=&quot;html_5335bbcd624aeedfd418f1f2a4f78568&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;송악산(절울이)&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_41832eb6330c4e389e47178620179ea7.setContent(html_5335bbcd624aeedfd418f1f2a4f78568);
#
#
#         marker_027f0fc06de4933bd4247b409950f49b.bindPopup(popup_41832eb6330c4e389e47178620179ea7)
#         ;
#
#
#
#
#             marker_027f0fc06de4933bd4247b409950f49b.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bc281f6e905ea0f6c5219c382e5fe761 = L.marker(
#                 [33.2042537, 126.281676],
#                 {}
#             ).addTo(feature_group_a3d6b7a64d2063a7d40b9477dbf00ba1);
#
#
#         var popup_ca276df655ac38d54eba02a2d85de049 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_46acdded60d400e41506ed73dd8b7aaf = $(`&lt;div id=&quot;html_46acdded60d400e41506ed73dd8b7aaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;섯알오름&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_ca276df655ac38d54eba02a2d85de049.setContent(html_46acdded60d400e41506ed73dd8b7aaf);
#
#
#         marker_bc281f6e905ea0f6c5219c382e5fe761.bindPopup(popup_ca276df655ac38d54eba02a2d85de049)
#         ;
#
#
#
#
#             marker_bc281f6e905ea0f6c5219c382e5fe761.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e4a595ce466f34471317d7062b2cf124 = L.marker(
#                 [33.3708091, 126.6935196],
#                 {}
#             ).addTo(feature_group_a3d6b7a64d2063a7d40b9477dbf00ba1);
#
#
#         var popup_0d1c8752145ea6135ffc7129eb0e67ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_92ae3058179fbc8b0c5f439b8aa0cb75 = $(`&lt;div id=&quot;html_92ae3058179fbc8b0c5f439b8aa0cb75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;물영아리&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : N&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_0d1c8752145ea6135ffc7129eb0e67ab.setContent(html_92ae3058179fbc8b0c5f439b8aa0cb75);
#
#
#         marker_e4a595ce466f34471317d7062b2cf124.bindPopup(popup_0d1c8752145ea6135ffc7129eb0e67ab)
#         ;
#
#
#
#
#             marker_e4a595ce466f34471317d7062b2cf124.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_12b9d92b3fe6c8d09a221575994b7630 = L.marker(
#                 [33.342895, 126.6494133],
#                 {}
#             ).addTo(feature_group_a3d6b7a64d2063a7d40b9477dbf00ba1);
#
#
#         var popup_7598d8758cc0e482d21e0b482fa68de6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_494681dc03855de19d4a688c41c9f218 = $(`&lt;div id=&quot;html_494681dc03855de19d4a688c41c9f218&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;머체오름&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&

# %%
오름
# Out:
#     읍면동       오름명                         소재지         위도          경도 주차장 화장실  \
# 0   대정읍  송악산(절울이)    제주특별자치도 서귀포시 대정읍 상모리 산 2  33.199409  126.290780   Y   Y
# 1   대정읍      섯알오름   제주특별자치도 서귀포시 대정읍 상모리 1618  33.204254  126.281676   Y   Y
# 2   대정읍     가시오름    제주특별자치도 서귀포시 대정읍 동일리 1209  33.253363  126.249055   N   N
# 3   대정읍       녹남봉   제주특별자치도 서귀포시 대정읍 신도리 1304  33.279815  126.195483   N   N
# 4   남원읍      물영아리  제주특별자치도 서귀포시 남원읍 수망리 산 189  33.370809  126.693520   Y   N
# ..  ...       ...                         ...        ...         ...  ..  ..
# 63  서홍동       시오름        제주특별자치도 서귀포시 서홍동 산 1  33.361667  126.529167   N   N
# 64  대륜동       고근산     제주특별자치도 서귀포시 서호동 1286-1  33.266364  126.512309   Y   Y
# 65  중문동      거린사슴      제주특별자치도 서귀포시 대포동 산 2-1  33.307313  126.454127   Y   Y
# 66  중문동     베릿내오름       제주특별자치도 서귀포시 중문동 3712  33.251430  126.434824   Y   Y
# 67  중문동       법정악        제주특별자치도 서귀포시 하원동 산 1  33.258346  126.452100   Y   Y
#
#     표고(m)     데이터기준일자
# 0   104.0  2021-05-10
# 1    40.7  2021-05-10
# 2   106.5  2021-05-10
# 3   100.4  2021-05-10
# 4   508.0  2021-05-10
# ..    ...         ...
# 63  757.8  2021-05-10
# 64  396.2  2021-05-10
# 65  742.9  2021-05-10
# 66  101.2  2021-05-10
# 67  760.1  2021-05-10
#
# [68 rows x 9 columns]

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

locations = [[33.24275343637512, 126.31353238508069],
             [33.46220372339229, 126.31353238508069]]

cluster = MarkerCluster(locations = locations)
cluster.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_135fbd93de8fa595a2721bccf544e172 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_135fbd93de8fa595a2721bccf544e172&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_135fbd93de8fa595a2721bccf544e172 = L.map(
#                 &quot;map_135fbd93de8fa595a2721bccf544e172&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e3b582f1acce715917395f785449736 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_135fbd93de8fa595a2721bccf544e172);
#
#
#             var marker_cluster_92951fb3884ffa00fc480196aed6aa5d = L.markerClusterGroup(
#                 {}
#             );
#             map_135fbd93de8fa595a2721bccf544e172.addLayer(marker_cluster_92951fb3884ffa00fc480196aed6aa5d);
#
#
#             var marker_9c962567f343281f8b87dd45a70afbf0 = L.marker(
#                 [33.24275343637512, 126.31353238508069],
#                 {}
#             ).addTo(marker_cluster_92951fb3884ffa00fc480196aed6aa5d);
#
#
#             var marker_979ad9007fb8a9f8126af4d95413adb5 = L.marker(
#                 [33.46220372339229, 126.31353238508069],
#                 {}
#             ).addTo(marker_cluster_92951fb3884ffa00fc480196aed6aa5d);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
