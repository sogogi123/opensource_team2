# %%
import numpy as np
import pandas as pd
import folium

오름 = pd.read_csv('o.csv', encoding='utf-8')
from folium.features import CustomIcon

m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'

주차장유 = folium.FeatureGroup(name='주차장유').add_to(m)
주차장무 = folium.FeatureGroup(name='주차장무',show =False).add_to(m)
주차장_정보없음 = folium.FeatureGroup(name='주차장 정보없음',show= False).add_to(m)
화장실유 = folium.FeatureGroup(name='화장실유').add_to(m)
화장실무 = folium.FeatureGroup(name='화장실무',show=False).add_to(m)
화장실_정보없음 = folium.FeatureGroup(name='화장실 정보없음',show= False).add_to(m)

for i in range(오름.shape[0]):
    parking_icon_image = 'parking.png'
    picon = CustomIcon(
        parking_icon_image,
        icon_size = (20, 20),
        popup_anchor = (30, -30),
    )
    if 오름.iloc[i]["주차장"] == 'Y':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip,
            icon = picon
        ).add_to(주차장유)
    elif 오름.iloc[i]["주차장"] == 'N':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(주차장무)
    else:
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(주차장_정보없음)
for i in range(오름.shape[0]):
    restroom_icon_image = 'restroom.png'
    ricon = CustomIcon(
        restroom_icon_image,
        icon_size = (20, 20),
        popup_anchor = (30, -30),
    )
    if 오름.iloc[i]["화장실"] == 'Y':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip,
            icon= ricon
        ).add_to(화장실유)
    elif 오름.iloc[i]["화장실"] == 'N':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(화장실무)
    else:
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(화장실_정보없음)
        
        
folium.LayerControl(collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f32268902c09b38c6b2eebfd1be7c27d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f32268902c09b38c6b2eebfd1be7c27d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f32268902c09b38c6b2eebfd1be7c27d = L.map(
#                 &quot;map_f32268902c09b38c6b2eebfd1be7c27d&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_861c4a6ddcd5b4fdebdac3069f599a06 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f32268902c09b38c6b2eebfd1be7c27d);
#
#
#             var feature_group_67f130207612e88cdd9799ea300934e3 = L.featureGroup(
#                 {}
#             ).addTo(map_f32268902c09b38c6b2eebfd1be7c27d);
#
#
#             var marker_83b10f7a1c139bbdbf8fd6156162d349 = L.marker(
#                 [33.3073168, 126.4548441],
#                 {}
#             ).addTo(feature_group_67f130207612e88cdd9799ea300934e3);
#
#
#         var custom_icon_178b2c93481ff91c71de6a147368294b = L.icon({&quot;iconSize&quot;: [20, 20], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [30, -30]});
#         marker_83b10f7a1c139bbdbf8fd6156162d349.setIcon(custom_icon_178b2c93481ff91c71de6a147368294b);
#
#
#         var popup_ba4e4ba8f2bbfc4f624e1dca6d2f6109 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f5c742fbd8606df3f026ca86cdfd3783 = $(`&lt;div id=&quot;html_f5c742fbd8606df3f026ca86cdfd3783&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;거린사슴&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_ba4e4ba8f2bbfc4f624e1dca6d2f6109.setContent(html_f5c742fbd8606df3f026ca86cdfd3783);
#
#
#         marker_83b10f7a1c139bbdbf8fd6156162d349.bindPopup(popup_ba4e4ba8f2bbfc4f624e1dca6d2f6109)
#         ;
#
#
#
#
#             marker_83b10f7a1c139bbdbf8fd6156162d349.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_59f2a6446c741f7674a14c0c7ad444a7 = L.marker(
#                 [33.4536212, 126.7191236],
#                 {}
#             ).addTo(feature_group_67f130207612e88cdd9799ea300934e3);
#
#
#         var custom_icon_8035c6eaf264dd9f46714b69944d1c28 = L.icon({&quot;iconSize&quot;: [20, 20], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [30, -30]});
#         marker_59f2a6446c741f7674a14c0c7ad444a7.setIcon(custom_icon_8035c6eaf264dd9f46714b69944d1c28);
#
#
#         var popup_703a57afe685fe70a9238808f324c73c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1d3e440ceaf5e63f31a2824be2b9339f = $(`&lt;div id=&quot;html_1d3e440ceaf5e63f31a2824be2b9339f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;거문오름&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_703a57afe685fe70a9238808f324c73c.setContent(html_1d3e440ceaf5e63f31a2824be2b9339f);
#
#
#         marker_59f2a6446c741f7674a14c0c7ad444a7.bindPopup(popup_703a57afe685fe70a9238808f324c73c)
#         ;
#
#
#
#
#             marker_59f2a6446c741f7674a14c0c7ad444a7.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c0c2c22290b12e4642dcfb6124dee553 = L.marker(
#                 [33.2663637, 126.5123088],
#                 {}
#             ).addTo(feature_group_67f130207612e88cdd9799ea300934e3);
#
#
#         var custom_icon_ac4ed74aab7939cfde8b728195de2c2c = L.icon({&quot;iconSize&quot;: [20, 20], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [30, -30]});
#         marker_c0c2c22290b12e4642dcfb6124dee553.setIcon(custom_icon_ac4ed74aab7939cfde8b728195de2c2c);
#
#
#         var popup_4c734d76b28d3def79be09ca95a1891f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3ccb277f4f3c3fc301ff044c3576f6d0 = $(`&lt;div id=&quot;html_3ccb277f4f3c3fc301ff044c3576f6d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;고근산&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_4c734d76b28d3def79be09ca95a1891f.setContent(html_3ccb277f4f3c3fc301ff044c3576f6d0);
#
#
#         marker_c0c2c22290b12e4642dcfb6124dee553.bindPopup(popup_4c
