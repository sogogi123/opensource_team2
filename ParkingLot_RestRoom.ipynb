# %%
import numpy as np
import pandas as pd
import folium

오름 = pd.read_csv('o.csv', encoding='utf-8')
from folium.features import CustomIcon

m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'

주차장유 = folium.FeatureGroup(name='주차장유').add_to(m)
주차장무 = folium.FeatureGroup(name='주차장무').add_to(m)
주차장_정보없음 = folium.FeatureGroup(name='주차장 정보없음',show= False).add_to(m)
화장실유 = folium.FeatureGroup(name='화장실유').add_to(m)
화장실무 = folium.FeatureGroup(name='화장실무').add_to(m)
화장실_정보없음 = folium.FeatureGroup(name='화장실 정보없음',show= False).add_to(m)

for i in range(오름.shape[0]):
    if 오름.iloc[i]["주차장"] == 'Y':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(주차장유)
    elif 오름.iloc[i]["주차장"] == 'N':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(주차장무)
    else:
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(주차장_정보없음)
for i in range(오름.shape[0]):
    if 오름.iloc[i]["화장실"] == 'Y':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(화장실유)
    elif 오름.iloc[i]["화장실"] == 'N':
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(화장실무)
    else:
        folium.Marker(
            [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
            popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
            주차장 : {오름.iloc[i]["주차장"]}<br>\
            화장실 : {오름.iloc[i]["화장실"]}<br>',
            tooltip = tooltip
        ).add_to(화장실_정보없음)
        
        
folium.LayerControl(collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_591f9cd819ddcb8b749b1cfb5869609f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_591f9cd819ddcb8b749b1cfb5869609f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_591f9cd819ddcb8b749b1cfb5869609f = L.map(
#                 &quot;map_591f9cd819ddcb8b749b1cfb5869609f&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6668e840d988d3279cd75b2f1f5f1706 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_591f9cd819ddcb8b749b1cfb5869609f);
#
#
#             var feature_group_55d26a55e4d9089307ae4dfd564bc087 = L.featureGroup(
#                 {}
#             ).addTo(map_591f9cd819ddcb8b749b1cfb5869609f);
#
#
#             var marker_34581dd965896bfed04ac60cd2b01ae5 = L.marker(
#                 [33.3073168, 126.4548441],
#                 {}
#             ).addTo(feature_group_55d26a55e4d9089307ae4dfd564bc087);
#
#
#         var popup_3ed26dfe3e06e7cad6921050bd0d7c9a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2895af82be390f8c5c7258b79ff65830 = $(`&lt;div id=&quot;html_2895af82be390f8c5c7258b79ff65830&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;거린사슴&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_3ed26dfe3e06e7cad6921050bd0d7c9a.setContent(html_2895af82be390f8c5c7258b79ff65830);
#
#
#         marker_34581dd965896bfed04ac60cd2b01ae5.bindPopup(popup_3ed26dfe3e06e7cad6921050bd0d7c9a)
#         ;
#
#
#
#
#             marker_34581dd965896bfed04ac60cd2b01ae5.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dac3551d93404ec8a49afe0999bf809e = L.marker(
#                 [33.2663637, 126.5123088],
#                 {}
#             ).addTo(feature_group_55d26a55e4d9089307ae4dfd564bc087);
#
#
#         var popup_ca09979a953e71c2f056281e73507101 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_90037e185244f23fb6b6e910a6b0bbfe = $(`&lt;div id=&quot;html_90037e185244f23fb6b6e910a6b0bbfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;고근산&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : Y&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_ca09979a953e71c2f056281e73507101.setContent(html_90037e185244f23fb6b6e910a6b0bbfe);
#
#
#         marker_dac3551d93404ec8a49afe0999bf809e.bindPopup(popup_ca09979a953e71c2f056281e73507101)
#         ;
#
#
#
#
#             marker_dac3551d93404ec8a49afe0999bf809e.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b2643a0cf449ba3cc6ccd58533223116 = L.marker(
#                 [33.2551426, 126.3683605],
#                 {}
#             ).addTo(feature_group_55d26a55e4d9089307ae4dfd564bc087);
#
#
#         var popup_46bb1631c5768f075d2eb47dababb87f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b0bf92ad5bfe6965b79afd3aa819383c = $(`&lt;div id=&quot;html_b0bf92ad5bfe6965b79afd3aa819383c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;군산&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : N&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_46bb1631c5768f075d2eb47dababb87f.setContent(html_b0bf92ad5bfe6965b79afd3aa819383c);
#
#
#         marker_b2643a0cf449ba3cc6ccd58533223116.bindPopup(popup_46bb1631c5768f075d2eb47dababb87f)
#         ;
#
#
#
#
#             marker_b2643a0cf449ba3cc6ccd58533223116.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fa0ef44fde1301964a9285feb9889ae5 = L.marker(
#                 [33.3050158, 126.3046682],
#                 {}
#             ).addTo(feature_group_55d26a55e4d9089307ae4dfd564bc087);
#
#
#         var popup_5f5dd6b5c6fdcf4557409aaea9fc7aed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_aa7545979db207628ac65a740425178b = $(`&lt;div id=&quot;html_aa7545979db207628ac65a740425178b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;남송이오름&lt;/strong&gt;&lt;br&gt;            주차장 : Y&lt;br&gt;            화장실 : N&lt;br&gt;&lt;/div&gt;`
